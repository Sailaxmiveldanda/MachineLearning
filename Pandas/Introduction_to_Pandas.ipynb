# %%
import pandas as pd

# %%
#Series DataType

cars = pd.Series(["Honda", "Tesla", "BMW"])

# %%
cars
# Out:
# 0    Honda
# 1    Tesla
# 2      BMW
# dtype: str

# %%
colors = pd.Series([1,2,3])

# %%
colors
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
#DataFrames - 2d

# %%
car_data = pd.DataFrame({"Name" : ["Sai", "Nik", "Ram"] , "Age" : [27,25,19]})

# %%
car_data
# Out:
#   Name  Age
# 0  Sai   27
# 1  Nik   25
# 2  Ram   19

# %%
#Import Data

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported_file.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported_file.csv")

# %%
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describing Data with Pandas

# %%
#attributes
car_sales.dtypes 

#function
# car_sales.to_csv()
# Out:
# Make               str
# Colour             str
# Odometer (KM)    int64
# Doors            int64
# Price              str
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='str')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     str
#  1   Colour         10 non-null     str
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000,2500,7500])

# %%
car_prices.mean()
# Out:
# np.float64(4333.333333333333)

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# # Viewing and Selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Lock(.loc)  and iLoc(.iloc)
animals = pd.Series(["Cat", "Dog" , "Parrot", "Bird", "Snake"])

# %%
animals
# Out:
# 0       Cat
# 1       Dog
# 2    Parrot
# 3      Bird
# 4     Snake
# dtype: str

# %%
animals = pd.Series(["Cat", "Dog" , "Parrot", "Bird", "Snake"], index= [0,2,4,6,8])

# %%
animals
# Out:
# 0       Cat
# 2       Dog
# 4    Parrot
# 6      Bird
# 8     Snake
# dtype: str

# %%
animals.loc[6]
# Out:
# 'Bird'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc
animals.iloc[2]
# Out:
# 'Parrot'

# %%
animals
# Out:
# 0       Cat
# 2       Dog
# 4    Parrot
# 6      Bird
# 8     Snake
# dtype: str

# %%
animals.iloc[3:]
# Out:
# 6     Bird
# 8    Snake
# dtype: str

# %%
animals.iloc[:3]
# Out:
# 0       Cat
# 2       Dog
# 4    Parrot
# dtype: str

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: str

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: str

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: str

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: str

# %%
car_sales[car_sales["Make"] =="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales["Odometer (KM)"] >= 55000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales["Make"] , car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean(numeric_only = True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
# if plot() gives error then run below codes
# %matplotlib inline 
# import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales.plot(x = "Make" , y = "Odometer (KM)")
# Out:
# <Axes: xlabel='Make'>

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\\$,\\.]', '', regex = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 car_sales["Price"].plot()
#
# File ~\Documents\sample_project\env\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\Documents\sample_project\env\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plt.draw_if_interactive()
#      73 return plot_obj.result
#
# File ~\Documents\sample_project\env\Lib\site-packages\pandas\plotting\_matplotlib\core.py:516, in MPLPlot.generate(self)
# ...

# %%
car_sales["Price"] = car_sales["Price"].str[:-2].astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales.plot(x = "Make", y = "Price")
# Out:
# <Axes: xlabel='Make'>

# %% [markdown]
# ## Manipulate Data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: str

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=False)
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
# column from series
seats_column = pd.Series([5,5,5,5,5])

# %%
car_sales["Seats"] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    NaN
# 6   honda   Blue          45698      4   7500    NaN
# 7   honda   Blue          54738      4   7000    NaN
# 8  toyota  White          60000      4   6250    NaN
# 9  nissan  White          31600      4   9700    NaN

# %%
car_sales["Seats"].fillna(5)
# Out:
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# 5    5.0
# 6    5.0
# 7    5.0
# 8    5.0
# 9    5.0
# Name: Seats, dtype: float64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    NaN
# 6   honda   Blue          45698      4   7500    NaN
# 7   honda   Blue          54738      4   7000    NaN
# 8  toyota  White          60000      4   6250    NaN
# 9  nissan  White          31600      4   9700    NaN

# %%
car_sales["Seats"] = car_sales["Seats"].fillna(5)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    5.0
# 6   honda   Blue          45698      4   7500    5.0
# 7   honda   Blue          54738      4   7000    5.0
# 8  toyota  White          60000      4   6250    5.0
# 9  nissan  White          31600      4   9700    5.0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    5.0
# 6   honda   Blue          45698      4   7500    5.0
# 7   honda   Blue          54738      4   7000    5.0
# 8  toyota  White          60000      4   6250    5.0
# 9  nissan  White          31600      4   9700    5.0

# %%
#column from list
fuel_economy = [7.5,9.2,5.0,9.6,8.7,5,7,7.6,8,9]
car_sales["fuel_economy"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_economy
# 0  toyota  White         150043      4   4000    5.0           7.5
# 1   honda    Red          87899      4   5000    5.0           9.2
# 2  toyota   Blue          32549      3   7000    5.0           5.0
# 3     bmw  Black          11179      5  22000    5.0           9.6
# 4  nissan  White         213095      4   3500    5.0           8.7
# 5  toyota  Green          99213      4   4500    5.0           5.0
# 6   honda   Blue          45698      4   7500    5.0           7.0
# 7   honda   Blue          54738      4   7000    5.0           7.6
# 8  toyota  White          60000      4   6250    5.0           8.0
# 9  nissan  White          31600      4   9700    5.0           9.0

# %%
car_sales["Milage"] = car_sales["Odometer (KM)"] / car_sales["fuel_economy"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_economy  \
# 0  toyota  White         150043      4   4000    5.0           7.5
# 1   honda    Red          87899      4   5000    5.0           9.2
# 2  toyota   Blue          32549      3   7000    5.0           5.0
# 3     bmw  Black          11179      5  22000    5.0           9.6
# 4  nissan  White         213095      4   3500    5.0           8.7
# 5  toyota  Green          99213      4   4500    5.0           5.0
# 6   honda   Blue          45698      4   7500    5.0           7.0
# 7   honda   Blue          54738      4   7000    5.0           7.6
# 8  toyota  White          60000      4   6250    5.0           8.0
# 9  nissan  White          31600      4   9700    5.0           9.0
#
#          Milage
# 0  20005.733333
# 1   9554.239130
# 2   6509.800000
# 3   1164.479167
# 4  24493.678161
# 5  19842.600000
# 6   6528.285714
# 7   7202.368421
# 8   7500.000000
# 9   3511.111111

# %%
car_sales["wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_economy  \
# 0  toyota  White         150043      4   4000    5.0           7.5
# 1   honda    Red          87899      4   5000    5.0           9.2
# 2  toyota   Blue          32549      3   7000    5.0           5.0
# 3     bmw  Black          11179      5  22000    5.0           9.6
# 4  nissan  White         213095      4   3500    5.0           8.7
# 5  toyota  Green          99213      4   4500    5.0           5.0
# 6   honda   Blue          45698      4   7500    5.0           7.0
# 7   honda   Blue          54738      4   7000    5.0           7.6
# 8  toyota  White          60000      4   6250    5.0           8.0
# 9  nissan  White          31600      4   9700    5.0           9.0
#
#          Milage  wheels
# 0  20005.733333       4
# 1   9554.239130       4
# 2   6509.800000       4
# 3   1164.479167       4
# 4  24493.678161       4
# 5  19842.600000       4
# 6   6528.285714       4
# 7   7202.368421       4
# ...

# %%
car_sales["Safety"] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_economy  \
# 0  toyota  White         150043      4   4000    5.0           7.5
# 1   honda    Red          87899      4   5000    5.0           9.2
# 2  toyota   Blue          32549      3   7000    5.0           5.0
# 3     bmw  Black          11179      5  22000    5.0           9.6
# 4  nissan  White         213095      4   3500    5.0           8.7
# 5  toyota  Green          99213      4   4500    5.0           5.0
# 6   honda   Blue          45698      4   7500    5.0           7.0
# 7   honda   Blue          54738      4   7000    5.0           7.6
# 8  toyota  White          60000      4   6250    5.0           8.0
# 9  nissan  White          31600      4   9700    5.0           9.0
#
#          Milage  wheels  Safety
# 0  20005.733333       4    True
# 1   9554.239130       4    True
# 2   6509.800000       4    True
# 3   1164.479167       4    True
# 4  24493.678161       4    True
# ...

# %%
car_sales = car_sales.drop("Milage", axis = 1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_economy  wheels  \
# 0  toyota  White         150043      4   4000    5.0           7.5       4
# 1   honda    Red          87899      4   5000    5.0           9.2       4
# 2  toyota   Blue          32549      3   7000    5.0           5.0       4
# 3     bmw  Black          11179      5  22000    5.0           9.6       4
# 4  nissan  White         213095      4   3500    5.0           8.7       4
# 5  toyota  Green          99213      4   4500    5.0           5.0       4
# 6   honda   Blue          45698      4   7500    5.0           7.0       4
# 7   honda   Blue          54738      4   7000    5.0           7.6       4
# 8  toyota  White          60000      4   6250    5.0           8.0       4
# 9  nissan  White          31600      4   9700    5.0           9.0       4
#
#    Safety
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True

# %%
car_sales_sampled = car_sales.sample(frac= 1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_economy  wheels  \
# 1   honda    Red          87899      4   5000    5.0           9.2       4
# 2  toyota   Blue          32549      3   7000    5.0           5.0       4
# 4  nissan  White         213095      4   3500    5.0           8.7       4
# 7   honda   Blue          54738      4   7000    5.0           7.6       4
# 8  toyota  White          60000      4   6250    5.0           8.0       4
# 5  toyota  Green          99213      4   4500    5.0           5.0       4
# 6   honda   Blue          45698      4   7500    5.0           7.0       4
# 3     bmw  Black          11179      5  22000    5.0           9.6       4
# 0  toyota  White         150043      4   4000    5.0           7.5       4
# 9  nissan  White          31600      4   9700    5.0           9.0       4
#
#    Safety
# 1    True
# 2    True
# 4    True
# 7    True
# 8    True
# 5    True
# 6    True
# 3    True
# 0    True
# 9    True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_economy  wheels  \
# 1   honda    Red          87899      4   5000    5.0           9.2       4
# 2  toyota   Blue          32549      3   7000    5.0           5.0       4
# 4  nissan  White         213095      4   3500    5.0           8.7       4
# 7   honda   Blue          54738      4   7000    5.0           7.6       4
# 8  toyota  White          60000      4   6250    5.0           8.0       4
# 5  toyota  Green          99213      4   4500    5.0           5.0       4
# 6   honda   Blue          45698      4   7500    5.0           7.0       4
# 3     bmw  Black          11179      5  22000    5.0           9.6       4
# 0  toyota  White         150043      4   4000    5.0           7.5       4
# 9  nissan  White          31600      4   9700    5.0           9.0       4
#
#    Safety
# 1    True
# 2    True
# 4    True
# 7    True
# 8    True
# 5    True
# 6    True
# 3    True
# 0    True
# 9    True

# %%
car_sales = car_sales_sampled.reset_index()

# %%
car_sales
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_economy  \
# 0      9  nissan  White          31600      4   9700    5.0           9.0
# 1      1   honda    Red          87899      4   5000    5.0           9.2
# 2      3     bmw  Black          11179      5  22000    5.0           9.6
# 3      2  toyota   Blue          32549      3   7000    5.0           5.0
# 4      6   honda   Blue          45698      4   7500    5.0           7.0
# 5      0  toyota  White         150043      4   4000    5.0           7.5
# 6      5  toyota  Green          99213      4   4500    5.0           5.0
# 7      4  nissan  White         213095      4   3500    5.0           8.7
# 8      7   honda   Blue          54738      4   7000    5.0           7.6
# 9      8  toyota  White          60000      4   6250    5.0           8.0
#
#    wheels  Safety
# 0       4    True
# 1       4    True
# 2       4    True
# 3       4    True
# 4       4    True
# 5       4    True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda k : k / 1.6)

# %%
car_sales
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  Seats  fuel_economy  \
# 0      9  nissan  White      19750.000      4   9700    5.0           9.0
# 1      1   honda    Red      54936.875      4   5000    5.0           9.2
# 2      3     bmw  Black       6986.875      5  22000    5.0           9.6
# 3      2  toyota   Blue      20343.125      3   7000    5.0           5.0
# 4      6   honda   Blue      28561.250      4   7500    5.0           7.0
# 5      0  toyota  White      93776.875      4   4000    5.0           7.5
# 6      5  toyota  Green      62008.125      4   4500    5.0           5.0
# 7      4  nissan  White     133184.375      4   3500    5.0           8.7
# 8      7   honda   Blue      34211.250      4   7000    5.0           7.6
# 9      8  toyota  White      37500.000      4   6250    5.0           8.0
#
#    wheels  Safety
# 0       4    True
# 1       4    True
# 2       4    True
# 3       4    True
# 4       4    True
# 5       4    True
# ...
